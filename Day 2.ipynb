# %% [markdown]
# # Pandas
# - Pandas is an open-source library that is made mainly for working with relational or labeled data both easily and intuitively.
# - It provides various data structures and operations for manipulating numerical data and time series.
# - This library is built on top of the NumPy library.
# - Pandas is fast and it has high performance & productivity for users.

# %%
#Installing libraries in python

# %%
# !pip install pandas

# %%
#Importing libraries

# %%
import pandas as pd

# %%
pandas.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pandas.DataFrame()
#
# NameError: name 'pandas' is not defined

# %%
a = pd.DataFrame()
a
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Pandas DataFrame

# %%
#Creating a dataFrame

# %%
dictionary = {
    'Name': ['A','B','C'],
    'Age' : [25,20,23],
    'Location' : ['Pune','Mumbai','Chennai'],
    'Subject Name' : ['ML','Python','DL']
}
dictionary
type(dictionary)
# Out:
# dict

# %%
dictionary
# Out:
# {'Name': ['A', 'B', 'C'],
#  'Age': [25, 20, 23],
#  'Location': ['Pune', 'Mumbai', 'Chennai'],
#  'Subject Name': ['ML', 'Python', 'DL']}

# %%
d1  = pd.DataFrame(dictionary)
# Out:
#   Name  Age Location Subject Name
# 0    A   25     Pune           ML
# 1    B   20   Mumbai       Python
# 2    C   23  Chennai           DL

# %%
data = pd.DataFrame({
    'Name': ['A','B','C'],
    'Age' : [25,20,23],
    'Location' : ['Pune','Mumbai','Chennai'],
    'Subject Name' : ['ML','Python','DL']
}
)

# %%
data
# Out:
#   Name  Age Location Subject Name
# 0    A   25     Pune           ML
# 1    B   20   Mumbai       Python
# 2    C   23  Chennai           DL

# %%
data['Subject Name']
# Out:
# 0        ML
# 1    Python
# 2        DL
# Name: Subject Name, dtype: object

# %%
data.Subject Name
# Out:
#   Cell In[27], line 1
#     data.Subject Name
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Loading external csv file

# %%
import pandas as pd

# %%
pd.read_csv('nba.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_csv('nba.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pd.read_csv(r"C:\Users\excel\OneDrive\Desktop\Datasets\nba.csv")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/Cars.csv')
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/Salaries.csv')
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
# pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#Extracting records from dataframe

# %%
df[['rank']]
# Out:
#          rank
# 0        Prof
# 1        Prof
# 2        Prof
# 3        Prof
# 4        Prof
# ..        ...
# 73       Prof
# 74  AssocProf
# 75       Prof
# 76       Prof
# 77       Prof
#
# [78 rows x 1 columns]

# %%
df[['rank','service','salary']]
# Out:
#          rank  service  salary
# 0        Prof       49  186960
# 1        Prof        6   93000
# 2        Prof       20  110515
# 3        Prof       31  131205
# 4        Prof       18  104800
# ..        ...      ...     ...
# 73       Prof       10  105450
# 74  AssocProf        6  104542
# 75       Prof       17  124312
# 76       Prof       14  109954
# 77       Prof       15  109646
#
# [78 rows x 3 columns]

# %%
df.ndim
# Out:
# 2

# %%
#Describing the dataset

# %%
df.head(2)
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000

# %%
df.describe(include=object)
# Out:
#         rank discipline gender
# count     78         78     78
# unique     3          2      2
# top     Prof          B   Male
# freq      46         42     39

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# gender        object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   gender      78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df['service'].describe()
# Out:
# count    78.000000
# mean     15.051282
# std      12.139768
# min       0.000000
# 25%       5.250000
# 50%      14.500000
# 75%      20.750000
# max      51.000000
# Name: service, dtype: float64

# %%
#Slicing dataframe

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service gender  salary
# 0       Prof          B   56       49   Male  186960
# 1       Prof          A   12        6   Male   93000
# 2       Prof          A   23       20   Male  110515
# 3       Prof          A   40       31   Male  131205
# 4       Prof          B   20       18   Male  104800
# 5       Prof          A   20       20   Male  122400
# 6  AssocProf          A   20       17   Male   81285
# 7       Prof          A   18       18   Male  126300
# 8       Prof          A   29       19   Male   94350
# 9       Prof          A   51       51   Male   57800

# %%
#loc

# %%
df.loc[0:10,'rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
# 5          Prof
# 6     AssocProf
# 7          Prof
# 8          Prof
# 9          Prof
# 10         Prof
# Name: rank, dtype: object

# %%
df.loc[0:10,'rank':'phd']
# Out:
#          rank discipline  phd
# 0        Prof          B   56
# 1        Prof          A   12
# 2        Prof          A   23
# 3        Prof          A   40
# 4        Prof          B   20
# 5        Prof          A   20
# 6   AssocProf          A   20
# 7        Prof          A   18
# 8        Prof          A   29
# 9        Prof          A   51
# 10       Prof          B   39

# %%
#Extract 5th,10th,18th rows from rank,phd

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.loc[[5,10,18],['rank','phd','salary']]
# Out:
#     rank  phd  salary
# 5   Prof   20  122400
# 10  Prof   39  128250
# 18  Prof   19  107300

# %%
#iloc

# %%
#First 5 records from rank to phd column

# %%
df.loc[0:5,'rank':'phd']
# Out:
#    rank discipline  phd
# 0  Prof          B   56
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40
# 4  Prof          B   20
# 5  Prof          A   20

# %%
df.iloc[0:6,0:3]
# Out:
#    rank discipline  phd
# 0  Prof          B   56
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40
# 4  Prof          B   20
# 5  Prof          A   20

# %%
#Extracting unique records

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
df['rank'].nunique()
# Out:
# 3

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Male      39
# Female    39
# Name: gender, dtype: int64

# %%
df['rank'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['discipline'].value_counts().plot(kind = 'pie',autopct = '%0.0f%%')
# Out:
# <Axes: ylabel='discipline'>

# %% [markdown]
# # Pandas filtering Groupby

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
#Extract records where gender is female

# %%
df['gender'] == 'Female'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# Name: gender, Length: 78, dtype: bool

# %%
df[df['gender'] == 'Female']
# Out:
#          rank discipline  phd  service  gender  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
df.loc[df['gender'] == 'Female','gender':'salary']
# Out:
#     gender  salary
# 39  Female  129000
# 40  Female  137000
# 41  Female   74830
# 42  Female   80225
# 43  Female   77000
# 44  Female  151768
# 45  Female  140096
# 46  Female   74692
# 47  Female  103613
# 48  Female  111512
# 49  Female  122960
# 50  Female   97032
# 51  Female  127512
# 52  Female  105000
# 53  Female   73500
# 54  Female   62884
# 55  Female   72500
# 56  Female   77500
# 57  Female   72500
# 58  Female  144651
# 59  Female  103994
# 60  Female   92000
# 61  Female  103750
# 62  Female  109650
# 63  Female   91000
# 64  Female   73300
# 65  Female  117555
# 66  Female   63100
# 67  Female   90450
# 68  Female   77500
# 69  Female  116450
# 70  Female   78500
# 71  Female   71065
# 72  Female  161101
# 73  Female  105450
# 74  Female  104542
# 75  Female  124312
# 76  Female  109954
# 77  Female  109646

# %%
#Prof

# %%
df[df['rank'] == 'Prof']   #-> masking approach
# Out:
#     rank discipline  phd  service  gender  salary
# 0   Prof          B   56       49    Male  186960
# 1   Prof          A   12        6    Male   93000
# 2   Prof          A   23       20    Male  110515
# 3   Prof          A   40       31    Male  131205
# 4   Prof          B   20       18    Male  104800
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 8   Prof          A   29       19    Male   94350
# 9   Prof          A   51       51    Male   57800
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 18  Prof          A   19        7    Male  107300
# 19  Prof          A   29       27    Male  150500
# 21  Prof          A   33       30    Male  103106
# 24  Prof          A   30       23    Male   91100
# ...

# %%
#Gender = 'Female' and salary > 150000

# %%
# and -> &
# or -> |

df[(df['gender'] == 'Female') & (df['salary'] > 150000)]
# Out:
#     rank discipline  phd  service  gender  salary
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
df[(df['gender'] == 'Female') | (df['salary'] > 150000)]
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 19       Prof          A   29       27    Male  150500
# 27       Prof          A   45       43    Male  155865
# 31       Prof          B   22       21    Male  155750
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# ...

# %%
#Calculate average salary of those whose rank = 'prof' and gender = 'male'

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['discipline'].mode()
# Out:
# 0    B
# Name: discipline, dtype: object

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurtosis()
# Out:
# -0.4017126758820546

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
#Calculate average salary of those whose rank = 'prof' and gender = 'male'

# %%
len(df[(df['rank'] == 'Prof') & (df['gender'] == 'Male')])
# Out:
# 28

# %%
df[(df['rank'] == 'Prof') & (df['gender'] == 'Male')]['salary'].mean()
# Out:
# 124690.14285714286

# %%
df[(df['rank'] == 'Prof') & (df['gender'] == 'Male')]['discipline'].mode()
# Out:
# 0    A
# Name: discipline, dtype: object

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
print(df[df['rank'] == "Prof"]['salary'].mean())
print(df[df['rank'] == 'AssocProf']['salary'].mean())
print(df[df['rank'] == 'AsstProf']['salary'].mean())
# Out:
# 123624.80434782608
# 91786.23076923077
# 81362.78947368421

# %% [markdown]
# # GroupBy

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.groupby('rank')

# %%
df.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64

# %%
df.groupby('rank')['salary'].agg({'min','max','median','mean'})
# Out:
#              min     max           mean    median
# rank
# AssocProf  62884  119800   91786.230769  103613.0
# AsstProf   63100   97032   81362.789474   78500.0
# Prof       57800  186960  123624.804348  123321.5
